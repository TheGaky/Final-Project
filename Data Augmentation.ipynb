# %%
from PIL import Image, ImageFilter
import cv2

# %%
def change_brightness(image, factor):
    from PIL import Image, ImageEnhance
    
    im = Image.open(image)
    img_enhancer = ImageEnhance.Brightness(im)
    im = img_enhancer.enhance(factor)
    return im

# %%
def change_contrast(image, factor):
    from PIL import Image, ImageEnhance
    im = Image.open(image)
    
    img_enhancer = ImageEnhance.Contrast(im)
    im = img_enhancer.enhance(factor)
    return im

# %%
def blur(image, radius):
    from PIL import Image, ImageFilter 
    im = Image.open(image)
    
    im = im.filter(ImageFilter.GaussianBlur(radius = radius))
    return im

# %%
import os
folder = "/Users/gaky/Desktop/efir/off for use/off mix"
images = os.listdir(folder)

for i in images:
    if i == ".DS_Store":
        images.remove(i)

for i in range(len(images)):
    
    #ima = change_brightness(folder+"/"+images[i], 1.5)
    #ima = change_contrast(ima, 0.7)
    ima = blur(folder+"/"+images[i], 5)
    ima.save("/Users/gaky/Desktop/efir/off for use/off blur"+"/"+ str(i) +".jpg")

# %%
shit = blur("/Users/gaky/Desktop/efir/on for use/true low/name__M0026, time__2023-09-27 18_31_01.608625.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/45/wj5m3mk56b38wrkpv32mr0240000gn/T/ipykernel_83423/90388119.py in <module>
# ----> 1 shit = blur("/Users/gaky/Desktop/efir/on for use/true low/name__M0026, time__2023-09-27 18_31_01.608625.jpg")
#
# TypeError: blur() missing 1 required positional argument: 'radius'

# %%
shit = change_contrast("/Users/gaky/Desktop/efir/on for use/true low/name__M0026, time__2023-09-27 18_31_01.608625.jpg", 0.7)

# %%
shit
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
shit = change_brightness("/Users/gaky/Desktop/efir/on for use/true low/name__M0026, time__2023-09-27 18_31_01.608625.jpg", 1.5)

# %%
shit = change_contrast("/Users/gaky/Desktop/efir/on for use/true low/name__M0026, time__2023-09-27 18_31_01.608625.jpg", 2)
shit
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
image = "/Users/gaky/Desktop/efir/on for use/true low/name__M0026, time__2023-09-27 19_15_24.591526.jpg"
shit = change_brightness(image, 1.2)
shit = change_contrast(image, 5)
shit
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
def cock(image):
    shit = change_brightness(image, 1.2)
    shit = change_contrast(image, 5)
    print(shit)

# %%
image = "/Users/gaky/Desktop/efir/on for use/low valid/M0047.webshot.0.jpg"

# %%
shit = change_brightness(image, 1)
shit = change_contrast(image, 0.7)
shit
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
image = "/Users/gaky/Desktop/efir/off for use/off mix/0e86f51e-7849-423f-b281-278e159d2c2c.jpg"

# %%
im = "/Users/gaky/Desktop/efir/off for use/off mix/name__M0059, time__2023-09-09 07_33_32.768968.jpg"
#im = "/Users/gaky/Desktop/efir/off for use/off mix/name__M0047, time__2023-09-27 19_53_46.396882.jpg"
shit = change_brightness(im, 1)
shit = change_contrast(im, 0.7)
shit
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
